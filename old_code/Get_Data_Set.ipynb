# %%
import random, shutil, os, time
import numpy as np
import pandas as pd
from PIL import Image
from google_scraper import scrape

# %%
# size = 224, 224
images_per_class = 850
class_list = ['Nutria',
    'Virginia opossum',
    'Elk',
    'Columbian black-tailed deer',
    'Cougar',
    'Canada lynx',
    'Bobcat',
    'Deer',
    'Black bear',
    'Coyote',
    'Gray wolf',
    'Gray fox',
    'Red fox',
    'Raccoon',
    'Ringtail',
    'Mountain beaver',
    'Seals',
    'Sea lions',
    'Bald eagle',
    'Raven',
    ]

# %%
path = 'images/'

try:
    scrape(class_list, int(images_per_class), 'oregon_wildlife')
except Exception as e:
    print('Error. Skipping! {}'.format(e))
    
    ##Resize image
#     picture = os.listdir(path + folder)

#     for pic in picture:
#         img_name = str(int(time.time()))
#         try:
#             im = Image.open('{}{}/{}'.format(path, folder, pic)).convert('RGB')
#             im.thumbnail(im.size, Image.ANTIALIAS)
#             im.save('{}{}/{}.jpg'.format(path, folder, img_name), "JPEG", optimize=True)
#         except Exception as e:
# #             os.remove('{}{}/{}'.format(path, folder, pic))
#             print('Error. Skipping! {} image: {}'.format(e, pic))
#             continue

# %% [markdown]
# ## Backup

# %%
df = pd.read_csv('pokemon.csv', header='infer', delimiter=',')
pokemon_list = df['name'].tolist()
pokemon_list

# %% [markdown]
# ### Clean broken images

# %%
for filename in os.listdir('images'):
    for picture in os.listdir('images/' + filename):
        if picture.endswith('.jpg'):
            try:
                img=Image.open('images/' + filename + '/' + picture)
                img.verify()
            except:
                os.remove('Pokemons/' + filename + '/' + picture)

# %% [markdown]
# ### Rename folders if it's required

# %%
for filename in os.listdir('data/raw'):
    if filename.startswith("pokemon_"):
        os.rename('data/raw/'+filename, 'data/raw/'+filename[8:])

# %%
class_list = [# 'camellias',
#     'western red cedar tree',
#     'redwood cedar tree',
    'rhododendrons',
    'shrub',
    'rose hips',
#     'cherry trees',
#     'Daphne flower'
    ]

# %%
def libraries():
    import numpy
    print(numpy.__version__)
    print('imported numpy')

# %%
numpy.__version__
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-fb7ec2e709c6> in <module>
# ----> 1 numpy.__version__
#
# NameError: name 'numpy' is not defined

# %%
libraries()
# Out:
# 1.16.2
# imported numpy

# %%
numpy.__version__
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-fb7ec2e709c6> in <module>
# ----> 1 numpy.__version__
#
# NameError: name 'numpy' is not defined

# %%
import numpy
numpy.__version__

# %%
# !ls
# Out:
# deer
# Get_Data_Set.ipynb
# google_scraper.py

# %%
import os

# %%
for item in os.scandir('deer'):
    print(item.is_dir())
# Out:
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# ...
